# %%
#Importing the required librarie
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
patient=pd.read_csv('heart_attack_dataset.csv')
patient
# Out:
#      Gender  Age  Blood Pressure (mmHg)  Cholesterol (mg/dL) Has Diabetes  \
# 0      Male   70                    181                  262           No
# 1    Female   55                    103                  253          Yes
# 2      Male   42                     95                  295          Yes
# 3      Male   84                    106                  270           No
# 4      Male   86                    187                  296          Yes
# ..      ...  ...                    ...                  ...          ...
# 995    Male   42                    125                  193          Yes
# 996    Male   80                    186                  267          Yes
# 997  Female   64                    108                  174          Yes
# 998  Female   84                    123                  195           No
# 999    Male   61                    155                  197           No
#
#     Smoking Status   Chest Pain Type                            Treatment
# ...

# %%
patient.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Gender                 1000 non-null   object
#  1   Age                    1000 non-null   int64
#  2   Blood Pressure (mmHg)  1000 non-null   int64
#  3   Cholesterol (mg/dL)    1000 non-null   int64
#  4   Has Diabetes           1000 non-null   object
#  5   Smoking Status         1000 non-null   object
#  6   Chest Pain Type        1000 non-null   object
#  7   Treatment              1000 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
patient['Treatment'].value_counts()
# Out:
# Treatment
# Lifestyle Changes                      269
# Coronary Artery Bypass Graft (CABG)    252
# Angioplasty                            247
# Medication                             232
# Name: count, dtype: int64

# %%
patient['Chest Pain Type'].value_counts()
# Out:
# Chest Pain Type
# Non-anginal Pain    261
# Asymptomatic        255
# Typical Angina      243
# Atypical Angina     241
# Name: count, dtype: int64

# %%
patient['Smoking Status'].unique()
# Out:
# array(['Never', 'Current', 'Former'], dtype=object)

# %%
patient.isna().sum()
# Out:
# Gender                   0
# Age                      0
# Blood Pressure (mmHg)    0
# Cholesterol (mg/dL)      0
# Has Diabetes             0
# Smoking Status           0
# Chest Pain Type          0
# Treatment                0
# dtype: int64

# %%
patient_df=patient.drop(['Treatment'],axis=1)
patient_df
# Out:
#      Gender  Age  Blood Pressure (mmHg)  Cholesterol (mg/dL) Has Diabetes  \
# 0      Male   70                    181                  262           No
# 1    Female   55                    103                  253          Yes
# 2      Male   42                     95                  295          Yes
# 3      Male   84                    106                  270           No
# 4      Male   86                    187                  296          Yes
# ..      ...  ...                    ...                  ...          ...
# 995    Male   42                    125                  193          Yes
# 996    Male   80                    186                  267          Yes
# 997  Female   64                    108                  174          Yes
# 998  Female   84                    123                  195           No
# 999    Male   61                    155                  197           No
#
#     Smoking Status   Chest Pain Type
# 0            Never    Typical Angina
# ...

# %%
treat=patient[['Treatment']]
treat
# Out:
#                                Treatment
# 0                      Lifestyle Changes
# 1                            Angioplasty
# 2                            Angioplasty
# 3    Coronary Artery Bypass Graft (CABG)
# 4                             Medication
# ..                                   ...
# 995                          Angioplasty
# 996  Coronary Artery Bypass Graft (CABG)
# 997  Coronary Artery Bypass Graft (CABG)
# 998                    Lifestyle Changes
# 999                    Lifestyle Changes
#
# [1000 rows x 1 columns]

# %%
sns.heatmap(patient_df[['Age','Blood Pressure (mmHg)','Cholesterol (mg/dL)']].corr(),annot=True)
# Out:
# <Axes: >

# %%
#Generating a scatterplot using original dataset 'patient'
sns.scatterplot(x=patient['Blood Pressure (mmHg)'],y=patient['Treatment'])
# Out:
# <Axes: xlabel='Blood Pressure (mmHg)', ylabel='Treatment'>

# %%
#Generating a scatterplot using original dataset 'patient'
sns.scatterplot(x=patient['Cholesterol (mg/dL)'],y=patient['Treatment'])
# Out:
# <Axes: xlabel='Cholesterol (mg/dL)', ylabel='Treatment'>

# %%
sns.displot(patient['Blood Pressure (mmHg)'],kind='kde')

# %%
#Generating a countplot using original dataset 'patient'
sns.countplot(x=patient['Has Diabetes'],hue=patient['Treatment'],data=patient)
# Out:
# <Axes: xlabel='Has Diabetes', ylabel='count'>

# %%
#Generating a countplot using original dataset 'patient'
sns.countplot(x=patient['Chest Pain Type'],hue=patient['Treatment'],data=patient)
# Out:
# <Axes: xlabel='Chest Pain Type', ylabel='count'>

# %%
sns.boxplot(patient[['Blood Pressure (mmHg)','Cholesterol (mg/dL)']])
# Out:
# <Axes: >

# %%
sns.boxplot(patient['Age'])
# Out:
# <Axes: ylabel='Age'>
